# %% [markdown]
# ### Image Aruthmatics

# %%
import cv2 
import numpy as np

# %%
image1 = cv2.imread('lenna.png')
image2 = cv2.imread('sun.png')

# %%
cv2.imshow('lenna',image1)
cv2.imshow('sun',image2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image1.shape,image2.shape
# Out:
# ((512, 512, 3), (512, 512, 3))

# %%
added_image = cv2.add(image1,image2)

# %%
cv2.imshow('added_image',added_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
new_img = image1 + image2
cv2.imshow('Sun',new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
new_img1 = new_img - image2
cv2.imshow('Sun',new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ###  Image subtraction

# %%
subtracted_image = cv2.subtract(image1,image2)

cv2.imshow('subtracted_image',subtracted_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
subtracted_image = cv2.subtract(image2,image1)

cv2.imshow('subtracted_image',subtracted_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
subtracted_image = cv2.subtract(added_image,image2)

cv2.imshow('subtracted_image',subtracted_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
subtracted_image = cv2.subtract(added_image,image1)

cv2.imshow('subtracted_image',subtracted_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('Added with scaler',image1+30)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('subtracted with scaler',image1-30)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Image Blending

# %%
alpha = 0.5
blended_image = cv2.addWeighted(image1,alpha,image2,1-alpha,0)

cv2.imshow('Blended Image',blended_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
alpha = 0.25
blended_image = cv2.addWeighted(image1,alpha,image2,1-alpha,0)

cv2.imshow('Blended Image',blended_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
alpha = 0.55
blended_image = cv2.addWeighted(image1,alpha,image2,1-alpha,0)

cv2.imshow('Blended Image',blended_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ###  Image multiply and divide

# %%
brighted_image = cv2.multiply(image1,1.5)    # 1.5 increases brightness
darked_image = cv2.divide(image1,2.5)    # 2.5 decreases brightness

cv2.imshow('Brighted Image',brighted_image)
cv2.imshow('Original Image',image1)
cv2.imshow('Darked Image',darked_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
13 & 7  # 1101 and 0111 Binary number of 13 & 7 and give 0101 which is 5(AND Operation)
# Out:
# 5

# %%
13|7  # 1100 and 0111 gives 1111 which is 15(OR Operation)
# Out:
# 15

# %% [markdown]
# ### Bitwise Operator

# %% [markdown]
# #### 1] Bitwise AND

# %%
img1 = cv2.imread('input1.png')
img2 = cv2.imread('input2.png')

cv2.imshow('input1 Image',img1)
cv2.imshow('input2 Image',img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# AND is applied over the image inputs with applied parameters
dest_and = cv2.bitwise_and(img1,img2,mask = None)

cv2.imshow('ANDed Image',dest_and)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
dest2 = cv2.bitwise_and(image1,image2,mask = None)

cv2.imshow('ANDed Image',dest2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### 2] Bitwise OR

# %%
# OR is applied over the image inputs with applied parameters
dest_or = cv2.bitwise_or(img1,img2,mask = None)

cv2.imshow('ORed Image',dest_or)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
dest2 = cv2.bitwise_or(image1,image2,mask = None)

cv2.imshow('ored Image',dest2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### 3] Bitwise XOR

# %%
13^7
# Out:
# 10

# %%
dest_xor = cv2.bitwise_xor(img1,img2,mask = None)

cv2.imshow('XORed Image',dest_xor)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
dest2 = cv2.bitwise_xor(image1,image2,mask = None)

cv2.imshow('XORed Image',dest2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### 4]Bitwise NOT

# %%
dest_not1 = cv2.bitwise_not(img1,mask = None)
dest_not2 = cv2.bitwise_not(img2,mask = None)

cv2.imshow('NOT Image1',dest_not1)
cv2.imshow('NOT Image2',dest_not2)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
lena_not = cv2.bitwise_not(image1,mask = None)

cv2.imshow('NOT on Leena',lena_not)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
sun_not = cv2.bitwise_not(image2,mask = None)

cv2.imshow('NOT on sun',sun_not)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Image Masking

# %%
img = cv2.imread('rgy.jpg')

cv2.imshow('My Image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# The kernal  to be used for dilation purpose
kernal = np.ones((5,5),np.uint8)

# converting the imagfe to HSV format
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# defining the lower and upper values of HSV, this will detect yellow colour
Lower_hsv = np.array([20, 70, 100])
Upper_hsv = np.array([30, 255, 255])

# creating the mask by eroding, morphing, dilating process
Mask = cv2.inRange(hsv, Lower_hsv, Upper_hsv)
Mask = cv2.erode(Mask, kernal, iterations = 1)
Mask = cv2.morphologyEx(Mask, cv2.MORPH_OPEN, kernal)
Mask = cv2.dilate(Mask, kernal, iterations = 1)

# Inverting the mask by performing bitwise-not opoeration
Mask = cv2.bitwise_not(Mask)

# Displaying the image
cv2.imshow('My Image',img)
cv2.imshow('Mask', Mask)
cv2.waitKey(0)

# closing all open windows
cv2.destroyAllWindows()

# %%
mask_yellow = cv2.bitwise_not(Mask)
Mask = cv2.bitwise_and(img, img, mask = mask_yellow)

# %%
# Displaying the image
cv2.imshow('Mask', Mask)
cv2.waitKey(0)

# closing all open windows
cv2.destroyAllWindows()

# %% [markdown]
# ### Splitting Channels

# %%
image = cv2.imread('lenna.png')

cv2.imshow('Original',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
channels = cv2.split(image)

# %%
len(channels)
# Out:
# 3

# %%
channels[0]
# Out:
# array([[125, 125, 133, ..., 122, 110,  90],
#        [125, 125, 133, ..., 122, 110,  90],
#        [125, 125, 133, ..., 122, 110,  90],
#        ...,
#        [ 60,  60,  58, ...,  84,  76,  79],
#        [ 57,  57,  62, ...,  79,  81,  81],
#        [ 57,  57,  62, ...,  79,  81,  81]], dtype=uint8)

# %%
blue, green, red = channels

# %%
blue.shape, green.shape, red.shape
# Out:
# ((512, 512), (512, 512), (512, 512))

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,3,1)
plt.title('Blue Channel')
plt.imshow(blue, cmap = 'gray')

plt.subplot(1,3,2)
plt.title('Green Channel')
plt.imshow(green, cmap = 'gray')

plt.subplot(1,3,3)
plt.title('Red Channel')
plt.imshow(red, cmap = 'gray')

# %%
 from PIL import Image

# %%
img = Image.open('lenna.png')

# %%
r, g, b = img.split()

# %%
g
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %% [markdown]
# ### Merging the channels

# %%
merged_image = cv2.merge([blue, green, red])

# %%
cv2.imshow("Final Image", merged_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
merged_image = cv2.merge([green, red, blue])
cv2.imshow("Final Image", merged_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
merged_image = cv2.merge([red, red, blue])
cv2.imshow("Final Image", merged_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.__version__
# Out:
# '4.9.0'

# %%
new_channel = np.zeros([512,512],dtype = np.uint8)+255

# %%
new_channel
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
marged_image = cv2.merge([blue,red,new_channel])
cv2.imshow("Final Image", merged_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Color spaces Models

# %%
image = Image.open('lenna.png')

cmyk_image = image.convert('CMYK')

cmyk_image.save('cmyk_image.jpg')

c,m,y,k = cmyk_image.split()

# %%
cmyk_image.show()

# %%
gray_image = image.convert('L')

# %%
gray_image
# Out:
# <PIL.Image.Image image mode=L size=512x512>
